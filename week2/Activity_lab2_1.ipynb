# %% [markdown]
# Activity 2.1: Logic Tracing Sandbox Analyze and execute the following optimized blocks within Google Colab or VS Code:

# %%
#Block A : Evaluation Check
temp = 25
is_raining = True

if temp > 20 and not is_raining:
    print("Perfect day for a picnic!")
elif temp <= 20 or is_raining:
    print("Stay indoors or bring an umbrella.")
else:
    print("Unsure about the weather.")
# Out:
# Stay indoors or bring an umbrella.

# %% [markdown]
# #Block A : Evaluation Check
# วิเคราะห์ทีละขั้น
#
# กำหนดค่า
# temp = 25
# is_raining = True
#
# ตรวจสอบเงื่อนไขแรก
# temp > 20 and not is_raining
#
# แยกเป็นสองส่วน
#
# ส่วนที่ 1
#
# temp > 20
#
# คือ
#
# 25 > 20
#
# ผลลัพธ์
#
# True
#
# ส่วนที่ 2
#
# not is_raining
#
# เนื่องจาก
#
# is_raining = True
#
# ดังนั้น
#
# not True
#
# ผลลัพธ์
#
# False
#
# นำมารวมกัน
#
# True and False
#
# ได้
#
# False
#
# จึงไม่เข้า if
#
# ตรวจสอบ elif
# temp <= 20 or is_raining
#
# แยกเป็นสองส่วน
#
# 25 <= 20
#
# ได้
#
# False
#
# อีกส่วน
#
# is_raining
#
# ได้
#
# True
#
# ดังนั้น
#
# False or True
#
# ได้
#
# True
#
# จึงเข้าเงื่อนไขนี้
#
# โปรแกรมจะแสดง
#
# Stay indoors or bring an umbrella.

# %%
#Block B : Vectorized Filter
phrase = "Python 2026 Engine"

consonants = {
    c.lower()
    for c in phrase
    if c.isalpha() and c.lower() not in "aeiou"
}

print(f"Unique consonants: {consonants}")
# Out:
# Unique consonants: {'p', 'g', 'h', 't', 'n', 'y'}

# %% [markdown]
# #Block B : Vectorized Filter
# วิเคราะห์ทีละขั้น
#
# กำหนดข้อความ
#
# phrase = "Python 2026 Engine"
#
# โปรแกรมจะวนดูทีละตัวอักษร
#
# P
# y
# t
# h
# o
# n
#
# 2
# 0
# 2
# 6
#
# E
# n
# g
# i
# n
# e

# %% [markdown]
# ตรวจสอบ
# c.isalpha()
#
# เลือกเฉพาะตัวอักษร
#
# จึงตัด
#
# 2
# 0
# 2
# 6
#
# ออก
#
# เหลือ
#
# P
# y
# t
# h
# o
# n
# E
# n
# g
# i
# n
# e

# %% [markdown]
# ตรวจสอบ
# c.lower() not in "aeiou"
#
# ตัดสระออก
#
# สระที่ถูกลบคือ
#
# o
# E
# i
# e
#
# เหลือ
#
# p
# y
# t
# h
# n
# n
# g
# n

# %% [markdown]
# ใช้ Set
# {
# ...
# }
#
# Set จะเก็บข้อมูลที่ ไม่ซ้ำกัน
#
# ดังนั้น
#
# n
#
# ที่ซ้ำหลายครั้ง
#
# จะเหลือเพียงตัวเดียว

# %% [markdown]
# ผลลัพธ์
# Unique consonants: {'p', 'y', 't', 'h', 'n', 'g'}
#
# หมายเหตุ: เนื่องจากเป็น set ลำดับการแสดงผลอาจแตกต่างกัน เช่น
#
# {'g', 'h', 'n', 'p', 't', 'y'}
#
# หรือ
#
# {'y', 'p', 'g', 't', 'n', 'h'}
#
# ก็ถือว่าถูกต้อง เพราะ set ใน Python ไม่มีการเรียงลำดับข้อมูล
